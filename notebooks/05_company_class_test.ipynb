# %%
import pandas as pd
import sys
sys.path.append("../src")
from company_blueprint import Company
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df_apld = Company("Applied Digital", "NASDAQGS", "APLD", 173.6, .284, .226, -686.6, 8718.2)

# %%
# get_company_data()

# exact_comps_coverage()

# exact_comps()

# fuzzy_comps()
       
# stage_comps()
        
# exact_comps_valuation()
       
# stage_comps_coverage_and_valuation()
  
# stage_comps_coverage_median_mean()
     
# stage_comps_plus_margin_coverage_and_median()
    
# stage_comps_coverage_and_median_by_margin_bracket()
        
# get_ev_to_rev()

# comps_minus_capex_coverage()

# comps_minus_capex()

# fuzzy_comps_minus_capex()

# %%
df_apld.get_company_data()
# Out:
#       Company Name  Exchange Ticker  Total Revenue ($USDmm)  Revenue YoY  \
# 0  Applied Digital  NASDAQGS   APLD                   173.6        0.284
#
#    Gross Margin %  Capital Expenditure ($USDmm)  Capex to Rev Growth Bucket  \
# 0           0.226                        -686.6       -3.9551   High Growth
#
#   Capex Bucket    Margin Bucket Revenue Bucket     TEV     EV/Rev
# 0  Asset Light  Very Low Margin      $100-250M  8718.2  50.220046

# %%
df_apld.exact_comps_coverage()
# Out:
# 6

# %%
df_apld.exact_comps()
# Out:
#                           Company Name  Exchange Ticker  Year    EV/Rev
# 0                  FGI Industries Ltd.  NasdaqCM    FGI  2021       NaN
# 1  Global Crossing Airlines Group Inc.      NEOE    JET  2024  0.741287
# 2           Paragon Technologies, Inc.     OTCPK   PGNT  2019  0.102746
# 3           Paragon Technologies, Inc.     OTCPK   PGNT  2021  0.132768
# 4                       Urgent.ly Inc.  NasdaqCM    ULY  2022       NaN
# 5                WidePoint Corporation    NYSEAM    WYY  2024  0.291725

# %%
df_apld.fuzzy_comps()
# Out:
#                                   Company Name  Exchange  Ticker  Year  \
# 0                   PAR Technology Corporation      NYSE     PAR  2020
# 1          American Superconductor Corporation  NasdaqGS    AMSC  2021
# 2                  Reading International, Inc.  NasdaqCM     RDI  2022
# 3          Public Policy Holding Company, Inc.       AIM    PPHC  2021
# 4              The ONE Group Hospitality, Inc.  NasdaqCM    STKS  2020
# 5                              SmartRent, Inc.      NYSE    SMRT  2022
# 6                        Armlogi Holding Corp.  NasdaqGM    BTOC  2024
# 7                                Netlist, Inc.     OTCPK    NLST  2022
# 8                Beasley Broadcast Group, Inc.  NasdaqCM    BBGI  2021
# 9                          Redwire Corporation      NYSE     RDW  2022
# 10  Greenland Technologies Holding Corporation  NasdaqCM    GTEC  2020
# 11                          Graham Corporation      NYSE     GHM  2021
# ...

# %%
df_apld.stage_comps()
# Out:
#                 Company Name  Exchange Ticker  Year     EV/Rev  \
# 0          1stdibs.Com, Inc.  NasdaqGM   DIBS  2021   2.985394
# 1             Agilysys, Inc.  NasdaqGS   AGYS  2022   9.958268
# 2                Agora, Inc.  NasdaqGS    API  2021   6.655952
# 3                Air T, Inc.  NasdaqCM   AIRT  2022   1.042781
# 4    Alkami Technology, Inc.  NasdaqGS   ALKT  2021   9.716163
# ..                       ...       ...    ...   ...        ...
# 98            Veritone, Inc.  NasdaqGM   VERI  2022   1.311289
# 99     Viant Technology Inc.  NasdaqGS    DSP  2021   0.527889
# 100   Virco Mfg. Corporation  NasdaqGM   VIRC  2022   0.437040
# 101    WidePoint Corporation    NYSEAM    WYY  2024   0.291725
# 102            Wingstop Inc.  NasdaqGS   WING  2019  14.303455
#
#         Margin Bucket
# 0         High Margin
# 1     High Mid margin
# 2     High Mid margin
# 3          Low Margin
# 4     High Mid margin
# ..                ...
# 98   Very High Margin
# ...

# %%
df_apld.exact_comps_valuation()
# Out:
#    Mean EV/Rev  Min EV/Rev  Max EV/Rev
# 0     0.317132    0.102746    0.741287

# %%
df_apld.stage_comps_coverage_and_valuation()
# Out:
#    Num of Observations  Mean EV/Rev
# 0                  103     5.292362

# %%
df_apld.stage_comps_coverage_median_mean()
# Out:
#    Num of Observations  Median EV/Rev  Mean EV/Rev
# 0                  103       1.967311     5.292362

# %%
df_apld.stage_comps_plus_margin_coverage_and_median()
# Out:
#      Margin Bucket  Num of Observations  Median EV/Rev
# 0  Very Low Margin                   11       0.741287

# %%
df_apld.stage_comps_coverage_and_median_by_margin_bracket()
# Out:
#   Revenue Bucket Margin Bracket  Num of Observations  Median EV/Rev  \
# 0      $100-250M   Lower Margin                   51       1.031678
# 1      $100-250M  Higher Margin                   52       4.459336
#
#    Mean_EV_Rev
# 0     4.586834
# 1    10.034826

# %%
df_apld.comps_minus_capex_coverage()
# Out:
# 11

# %%
df_apld.comps_minus_capex()
# Out:
#                            Company Name  Exchange Ticker  Year     EV/Rev
# 0           Applied Digital Corporation  NasdaqGS   APLD  2024  12.989796
# 1                   FGI Industries Ltd.  NasdaqCM    FGI  2021        NaN
# 2   Global Crossing Airlines Group Inc.      NEOE    JET  2024   0.741287
# 3                  Kura Sushi USA, Inc.  NasdaqGM   KRUS  2023   4.454409
# 4              Microvast Holdings, Inc.  NasdaqCM   MVST  2022   1.864059
# 5            Paragon Technologies, Inc.     OTCPK   PGNT  2019   0.102746
# 6            Paragon Technologies, Inc.     OTCPK   PGNT  2021   0.132768
# 7                       Plug Power Inc.  NasdaqCM   PLUG  2019   5.715652
# 8             SkyWater Technology, Inc.  NasdaqCM   SKYT  2022   1.795679
# 9                        Urgent.ly Inc.  NasdaqCM    ULY  2022        NaN
# 10                WidePoint Corporation    NYSEAM    WYY  2024   0.291725

# %%
df_apld.fuzzy_comps_minus_capex()
# Out:
#                            Company Name  Exchange Ticker  Year     EV/Rev  \
# 0                       PagerDuty, Inc.      NYSE     PD  2020  14.548221
# 1           Applied Digital Corporation  NasdaqGS   APLD  2024  12.989796
# 2                    Cipher Mining Inc.  NasdaqGS   CIFR  2024  10.651685
# 3              Microvast Holdings, Inc.  NasdaqCM   MVST  2021   8.271053
# 4            PAR Technology Corporation      NYSE    PAR  2020   6.567353
# ..                                  ...       ...    ...   ...        ...
# 73       Hydrofarm Holdings Group, Inc.  NasdaqCM   HYFM  2019        NaN
# 74                     MediaAlpha, Inc.      NYSE    MAX  2019        NaN
# 75             Microvast Holdings, Inc.  NasdaqCM   MVST  2020        NaN
# 76  Public Policy Holding Company, Inc.       AIM   PPHC  2020        NaN
# 77                       Urgent.ly Inc.  NasdaqCM    ULY  2022        NaN
#
#        Growth Bucket     Margin Bucket Revenue Bucket
# ...

# %%
df_apld.change_in_ev_rev_by_margin()
# Out:
# '-1.22602368650634 < 0 → margin penalized'

# %%
df_apld.valuation_growth_vs_narrative()
# Out:
#                          Metric  \
# 0                        Actual
# 1           Explained by Growth
# 2  Explained by Growth + Margin
# 3  Narrative/Future Assumptions
#
#                                              Formula    Result
# 0                                             EV/Rev  1.000000
# 1        (Stage Comps Median EV/Rev)/(Actual EV/Rev)  0.039174
# 2  (Stage + Margin Comps Median EV/Rev)/(Actual E...  0.014761
# 3  1-(Stage + Margin Comps Median EV/Rev)/(Actual...  0.985239
